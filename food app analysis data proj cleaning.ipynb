# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings("ignore")

def read_zomato_dataset():
    hotels=pd.read_csv(r'C:\Users\Kissinger\Downloads\zomato.csv')
    return hotels
read_zomato_dataset()
# Out:
#                                                  address  \
# 0      942, 21st Main Road, 2nd Stage, Banashankari, ...
# 1      2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...
# 2      1112, Next to KIMS Medical College, 17th Cross...
# 3      1st Floor, Annakuteera, 3rd Stage, Banashankar...
# 4      10, 3rd Floor, Lakshmi Associates, Gandhi Baza...
# ...                                                  ...
# 56247  Four Points by Sheraton Bengaluru, 43/3, White...
# 56248  Number 10, Garudachar Palya, Mahadevapura, Whi...
# 56249  Sheraton Grand Bengaluru Whitefield Hotel & Co...
# 56250  Sheraton Grand Bengaluru Whitefield Hotel & Co...
# 56251  ITPL Main Road, KIADB Export Promotion Industr...
#
#                                                     name online_order  \
# 0                                                  Jalsa          Yes
# 1                                         Spice Elephant          Yes
# ...

# %%
def remove_unwanted_columns():
    hotels = read_zomato_dataset()
    hotels.drop(['address','phone'], axis=1, inplace=True)
    return hotels

# %%
def rename_columns():
    #rename columns,  only these columns are allowed in the dataset
    # 1.	Id
    # 2.	Name
    # 3.	online_order
    # 4.	book_table
    # 5.	rating
    # 6.	votes
    # 7.	location
    # 8.	rest_type
    # 9.	dish_liked
    # 10.	cuisines
    # 11.	approx_cost
    # 12.	type
    hotels = remove_unwanted_columns()
    hotels.columns = ['name','online_order','book_table','rating','votes','location','rest_type','dish_liked','cuisines','approx_cost','type']
    return hotels

# %%
#handle  null values of each column
def null_value_check():
    hotels=rename_columns()
    
    #deleting null values of name column
    
    hotels.drop(hotels[hotels['name'].isna()].index, axis=0, inplace=True)
    
    #handling null values of online_order
    hotels['online_order'].fillna('NA', inplace=True)
    
    #handling null values of book_table
    hotels['book_table'].fillna('NA', inplace=True)
    
    #handling null values of rating
    hotels.drop(hotels[hotels['rating'].isna()].index, axis=0, inplace=True)
    
    #handling null values of votes
    hotels.drop(hotels[hotels['votes'].isna()].index, axis=0, inplace=True)
    
    #handling null values of location
    hotels['location'].fillna('NA', inplace=True)
    
    #handling null values of rest_type
    hotels['rest_type'].fillna('NA', inplace=True)
    
    #handling null values of dishliked
    hotels['dish_liked'].fillna('NA', inplace=True)
    
    #handling null values of cuisines
    hotels['cuisines'].fillna('NA', inplace=True)
    
    #handling null values of approxcost
    hotels.drop(hotels[hotels['approx_cost'].isna()].index, axis=0, inplace=True)
    
    #handling null values of type
    hotels['type'].fillna('NA', inplace=True)
    return hotels
null_value_check()
# Out:
#                                                     name online_order  \
# 0                                                  Jalsa          Yes
# 1                                         Spice Elephant          Yes
# 2                                        San Churro Cafe          Yes
# 3                                  Addhuri Udupi Bhojana           No
# 4                                          Grand Village           No
# ...                                                  ...          ...
# 56244                         The Farm House Bar n Grill           No
# 56246                                            Bhagini           No
# 56247  Best Brews - Four Points by Sheraton Bengaluru...           No
# 56250  Chime - Sheraton Grand Bengaluru Whitefield Ho...           No
# 56251                       The Nest - The Den Bengaluru           No
#
#       book_table  rating votes                    location  \
# 0            Yes   4.1/5   775                Banashankari
# ...

# %%
#find duplicates in the dataset
def find_duplicates():   
    #call null_value_check() function to get dataframe
    hotels=null_value_check()
    #droping the duplicates value keeping the first
    hotels.drop_duplicates(keep='first',inplace=True)
  
    return hotels

# %%
#removing irrelevant text from all the columns
def removing_irrelevant_text():
    #call find_duplicates() function to get dataframe
    hotels = find_duplicates()
    for column in hotels.columns:
        hotels.drop(hotels[hotels[column].str.contains('Rated', na=False)].index, axis=0, inplace=True)
        hotels.drop(hotels[hotels[column].str.contains('RATED', na=False)].index, axis=0, inplace=True)
    return hotels
removing_irrelevant_text()
# Out:
#                                                     name online_order  \
# 0                                                  Jalsa          Yes
# 1                                         Spice Elephant          Yes
# 2                                        San Churro Cafe          Yes
# 3                                  Addhuri Udupi Bhojana           No
# 4                                          Grand Village           No
# ...                                                  ...          ...
# 56244                         The Farm House Bar n Grill           No
# 56246                                            Bhagini           No
# 56247  Best Brews - Four Points by Sheraton Bengaluru...           No
# 56250  Chime - Sheraton Grand Bengaluru Whitefield Ho...           No
# 56251                       The Nest - The Den Bengaluru           No
#
#       book_table  rating votes                    location  \
# 0            Yes   4.1/5   775                Banashankari
# ...

# %%
#check for unique values in each column and handle the irrelevant values
def check_for_unique_values():
    #call removing_irrelevant_text() function to get dataframe
    hotels=removing_irrelevant_text()
    
    hotels.drop(hotels[~(hotels['online_order'].str.contains('Yes') | hotels['online_order'].str.contains('No'))].index, axis=0, inplace=True)
    hotels['rating'] = hotels['rating'].str.replace('/5','')
    hotels.loc[hotels['rating']=='NEW', 'rating']=0
    hotels.loc[hotels['rating']=='-', 'rating']=0
    return hotels

# %%
#remove the unknown character from the dataset and export it to "zomatocleaned.csv"
def remove_the_unknown_character():
    #call check_for_unique_values() function to get dataframe
    dataframe=check_for_unique_values()

    #remove unknown character from dataset
    dataframe['name'] = dataframe['name'].str.replace('Ã','',regex=True)
    dataframe['name'] = dataframe['name'].str.replace('Â','',regex=True)
    dataframe['name'] = dataframe['name'].str.replace('ƒ','',regex=True)
    dataframe['name'] = dataframe['name'].str.replace('‚','',regex=True)
    dataframe['name'] = dataframe['name'].str.replace('©','',regex=True)
    dataframe['name'] = dataframe['name'].str.replace('Caf @ ','Caf',regex=True)
    dataframe['name'] = dataframe['name'].str.replace('Caf & ','Caf',regex=True)
    dataframe['name'] = dataframe['name'].str.replace('24x7','24',regex=True)
    dataframe['name'] = dataframe['name'].str.replace('Caf Down The Alley','CafDown The Alley',regex=True)
    dataframe['name'] = dataframe['name'].str.replace('x ','',regex=True)
    dataframe['name'] = dataframe['name'].str.replace('DeliBox.in','DeliBoin',regex=True)
    dataframe['name'] = dataframe['name'].str.replace('Caf ','Caf',regex=True)
    dataframe['name'] = dataframe['name'].str.replace("x's",'s',regex=True)
    dataframe['name'] = dataframe['name'].str.replace("Cro»te",'Crote',regex=True)
    dataframe['name'] = dataframe['name'].str.replace("Rªveur",'Rveur',regex=True)
    dataframe['name'] = dataframe['name'].str.replace('Pinx- ','Pinx',regex=True)
    dataframe['name'] = dataframe['name'].str.replace('P¢tisserie','Ptisserie',regex=True)
    dataframe['name'] = dataframe['name'].str.replace('Caf- ','Caf',regex=True)
    dataframe['name'] = dataframe['name'].str.replace('Bo-','Bo',regex=True)
    dataframe['name'] = dataframe['name'].str.replace('Pi±ata','Piata',regex=True)
    dataframe['name'] = dataframe['name'].str.replace('100°C','100C',regex=True)
    dataframe['name'] = dataframe['name'].str.replace('Cr¨me','Crme',regex=True)
    dataframe['name'] = dataframe['name'].str.replace('Ony- ','Ony',regex=True)
    dataframe['name'] = dataframe['name'].str.replace('Delu- ','Delu',regex=True)
    dataframe['name'] = dataframe['name'].str.replace('Mum’s','Mums',regex=True)
    dataframe['name'] = dataframe['name'].str.replace('Sant Spa','SantSpa',regex=True)
    dataframe['name'] = dataframe['name'].str.replace('Brother’s','Brothers',regex=True)
    
    #export cleaned Dataset to newcsv file named "zomatocleaned.csv"
    dataframe.to_csv(r'C:\Users\Kissinger\Downloads\zomatocleaned.csv', index = False)
    
    return dataframe
remove_the_unknown_character()
# Out:
#                                                     name online_order  \
# 0                                                  Jalsa          Yes
# 1                                         Spice Elephant          Yes
# 2                                        San Churro Cafe          Yes
# 3                                  Addhuri Udupi Bhojana           No
# 4                                          Grand Village           No
# ...                                                  ...          ...
# 56244                         The Farm House Bar n Grill           No
# 56246                                            Bhagini           No
# 56247  Best Brews - Four Points by Sheraton Bengaluru...           No
# 56250  Chime - Sheraton Grand Bengaluru Whitefield Ho...           No
# 56251                       The Nest - The Den Bengaluru           No
#
#       book_table rating votes                    location  \
# 0            Yes    4.1   775                Banashankari
# ...
